# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as srn

# %%
dados = pd.read_csv('dados.csv', sep=";")
dados
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 0       106    SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1       113             SANTO ANGELO  16575.82     800669.92
# 2       118   SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3        13          CACAPAVA DO SUL  13674.54     485535.86
# 4       120              SAO GABRIEL  19912.38     533719.86
# ..      ...                      ...       ...           ...
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# 184      54           GETULIO VARGAS  16876.33        233.01
# 185     382          NOVA SANTA RITA  25938.38        310.58
# 186      60      GUARANI DAS MISSOES  24363.31        172.13
#
# [187 rows x 4 columns]

# %%
dados['PIB'].describe()
# Out:
# count       187.000000
# mean      19808.741337
# std       16984.223244
# min        8236.630000
# 25%       13621.455000
# 50%       17206.190000
# 75%       21429.165000
# max      223848.220000
# Name: PIB, dtype: float64

# %%
dados['VALOREMPENHO'].describe()
# Out:
# count    1.870000e+02
# mean     1.299844e+05
# std      1.615491e+05
# min      1.721300e+02
# 25%      5.251718e+04
# 50%      8.422816e+04
# 75%      1.538961e+05
# max      1.442760e+06
# Name: VALOREMPENHO, dtype: float64

# %%
srn.boxplot(dados['CODIGO'])
# Out:
# <Axes: >

# %%
srn.histplot(dados['PIB'])
# Out:
# <Axes: xlabel='PIB', ylabel='Count'>

# %%
  dados.loc[(dados['PIB'] >  100000 )]
# Out:
#     CODIGO MUNICIPIO        PIB  VALOREMPENHO
# 49     149   TRIUNFO  223848.22    1442759.82

# %%
srn.histplot(dados.PIB, kde=True, bins=10).set(title='PIB')
# Out:
# [Text(0.5, 1.0, 'PIB')]

# %%
srn.histplot(dados.VALOREMPENHO, kde=True, bins=10).set(title='VALOR EMPENHO')
# Out:
# [Text(0.5, 1.0, 'VALOR EMPENHO')]

# %%
 agrupado = dados.sort_values('PIB').head(10)
 agrupado = agrupado.iloc[:,1:3]
 agrupado
 agrupado.plot.bar(x='MUNICIPIO',y='PIB', color = 'gray')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
agrupado = dados.sort_values('VALOREMPENHO').head(10)
agrupado = agrupado.iloc[:,[1,3]]
agrupado
agrupado.plot.bar(x='MUNICIPIO',y='VALOREMPENHO', color = 'gray')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
plt.boxplot(dados.PIB, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3d6881850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d3d765d750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3d1744cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3d765e6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3d760eed0>],
#  'means': []}

# %%
plt.boxplot(dados.VALOREMPENHO, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d3d7471e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d3d7473210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d3d74714d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d3d74841d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d3d7435290>],
#  'means': []}

# %%
srn.boxplot(data=dados.PIB, orient ='v').set_title('PIB')
# Out:
# Text(0.5, 1.0, 'PIB')

# %%
srn.boxplot(data=dados, orient ='v')
# Out:
# <Axes: >

# %%
plt.scatter(x=dados.PIB, y=dados.VALOREMPENHO, color = 'blue', facecolors = 'none')
plt.title('dados') 
plt.xlabel('pib') 
plt.ylabel('empenho')
# Out:
# Text(0, 0.5, 'empenho')

# %%
srn.regplot(x=dados.PIB,y=dados.VALOREMPENHO, data = dados, x_jitter = 100000, fit_reg = False)
# Out:
# <Axes: xlabel='PIB', ylabel='VALOREMPENHO'>
